# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

df = pd.DataFrame(response.json()['results'])[['id','original_title' , 'overview']]
df
# Out:
#         id                                 original_title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                       千と千尋の神隠し
# 6      155                                The Dark Knight
# 7    19404                   दिलवाले दुल्हनिया ले जायेंगे
# 8      497                                 The Green Mile
# 9   496243                                            기생충
# 10     122  The Lord of the Rings: The Return of the King
# 11     680                                   Pulp Fiction
# 12  372058                                          君の名は。
# 13     429                Il buono, il brutto, il cattivo
# 14  157336                                   Interstellar
# 15      13                                   Forrest Gump
# 16     769                                     GoodFellas
# 17     346                                           七人の侍
# 18   12477                                          火垂るの墓
# 19     637                                La vita è bella
#
#                                              overview
# 0   Imprisoned in the 1940s for the double murder ...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   In the continuing saga of the Corleone crime f...
# 3   The true story of how businessman Oskar Schind...
# 4   The defense and the prosecution have rested an...
# 5   A young girl, Chihiro, becomes trapped in a st...
# 6   Batman raises the stakes in his war on crime. ...
# 7   Raj is a rich, carefree, happy-go-lucky second...
# 8   A supernatural tale set on death row in a Sout...
# 9   All unemployed, Ki-taek's family takes peculia...
# 10  As armies mass for a final battle that will de...
# 11  A burger-loving hit man, his philosophical par...
# 12  High schoolers Mitsuha and Taki are complete s...
# 13  While the Civil War rages on between the Union...
# 14  The adventures of a group of explorers who mak...
# 15  A man with a low IQ has accomplished great thi...
# 16  The true story of Henry Hill, a half-Irish, ha...
# 17  A samurai answers a village's request for prot...
# 18  In the final months of World War II, 14-year-o...
# 19  A touching story of an Italian book seller of ...

# %%
#for all pages : 
new_df = pd.DataFrame()
for i in range(1,5):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','original_title' , 'overview']]
    new_df = pd.concat([new_df,temp_df],ignore_index = True)

new_df
# Out:
#          id               original_title  \
# 0       278     The Shawshank Redemption
# 1       238                The Godfather
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4       389                 12 Angry Men
# ..      ...                          ...
# 75  1356039                 Contraataque
# 76    18491  新世紀エヴァンゲリオン劇場版 Air／まごころを、君に
# 77      975               Paths of Glory
# 78      901                  City Lights
# 79     8587                The Lion King
#
#                                              overview
# 0   Imprisoned in the 1940s for the double murder ...
# 1   Spanning the years 1945 to 1955, a chronicle o...
# 2   In the continuing saga of the Corleone crime f...
# 3   The true story of how businessman Oskar Schind...
# 4   The defense and the prosecution have rested an...
# ..                                                ...
# 75  When a hostage rescue mission creates a new en...
# 76  SEELE orders an all-out attack on NERV, aiming...
# 77  A commanding officer defends three scapegoats ...
# 78  A tramp falls in love with a beautiful blind f...
# 79  Young lion prince Simba, eager to one day beco...
#
# [80 rows x 3 columns]

# %%
new_df.to_csv('dataset_movies.csv')
