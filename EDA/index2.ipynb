# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('train.csv')

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 280.90it/s]00:00, 53.44it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:01<00:00, 26.87it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  6.91it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 102.63it/s]
